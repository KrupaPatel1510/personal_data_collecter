# %%
print("Welcome to the Interactive Personal Data Collector")
name = input("Enter your name: ")
age = int(input("Enter your age: "))
height = float(input("Enter your height in cm: "))
fav = int(input("Enter your favorite number:"))
Birth_year = 2026 - age
print("Thank you! Here is the information we collected:")
print("User Details")
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("favorite number:",fav)
print("Type and Memory Address")
print(type(name), id(name))
print(type(age), id(age))
print(type(height), id(height))
print(type(fav),id(fav))
print("Approx Birth Year:", Birth_year)
# Out:
# Welcome to the Interactive Personal Data Collector
# Enter your name: krupa
# Enter your age: 21
# Enter your height in cm: 5.5
# Enter your favorite number:5
# Thank you! Here is the information we collected:
# User Details
# Name: krupa
# Age: 21
# Height: 5.5
# favorite number: 5
# Type and Memory Address
# <class 'str'> 133912128676048
# <class 'int'> 11645992
# <class 'float'> 133912128531024
# <class 'int'> 11645480
# Approx Birth Year: 2005
